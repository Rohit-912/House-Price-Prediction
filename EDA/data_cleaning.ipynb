# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../data/raw/HousingData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
sns.scatterplot(x='CRIM',y='MEDV',data=df.dropna())
# Out:
# <Axes: xlabel='CRIM', ylabel='MEDV'>

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
sns.scatterplot(x='ZN',y='MEDV',data=df.dropna())
# Out:
# <Axes: xlabel='ZN', ylabel='MEDV'>

# %%
sns.scatterplot(x='INDUS',y='MEDV',data=df.dropna())
# Out:
# <Axes: xlabel='INDUS', ylabel='MEDV'>

# %%
sns.barplot(x='CHAS', y='MEDV', data=df.dropna())
# Out:
# <Axes: xlabel='CHAS', ylabel='MEDV'>

# %%
sns.scatterplot(x='NOX',y="INDUS",data=df.dropna())
# Out:
# <Axes: xlabel='NOX', ylabel='INDUS'>

# %%
sns.scatterplot(x='NOX',y="MEDV",data=df.dropna())
# Out:
# <Axes: xlabel='NOX', ylabel='MEDV'>

# %%
sns.scatterplot(x='RM',y="MEDV",data=df.dropna())
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
sns.histplot(x='CRIM',y='MEDV',data=df.dropna())
# Out:
# <Axes: xlabel='CRIM', ylabel='MEDV'>

# %%
df['CRIM_log'] = np.log1p(df['CRIM'])  # log1p means log(1 + CRIM)

# %%
sns.scatterplot(x='CRIM',y='MEDV',data=df.dropna())
# Out:
# <Axes: xlabel='CRIM', ylabel='MEDV'>

# %%
# Create the histogram with KDE
sns.histplot(df['CRIM'], bins=30, kde=True, color='skyblue')

# Add labels
plt.title('Distribution of CRIM (Crime Rate)')
plt.xlabel('CRIM')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#               CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM      1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150
# ZN       -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800
# INDUS     0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234
# CHAS     -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885
# NOX       0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188
# RM       -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000
# AGE       0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337
# DIS      -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246
# RAD       0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847
# TAX       0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048
# PTRATIO   0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501
# B        -0.381411  0.171303 -0.360532  0.051264 -0.380051  0.128069
# LSTAT     0.444943 -0.414193  0.590690 -0.047424  0.582641 -0.614339
# ...

# %%
df.drop('CRIM_log',axis=1,inplace=True)
